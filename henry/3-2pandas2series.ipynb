# %%
# 데이터분석이란 데이터를 불러와 수정,가공한후 분석을 통해
# 통찰력을 얻고 답을 찾아나가는 과정
# panda패키지는 1차원 배열인 series 와
# 2차원 배열인 DataFrame을 통해 데이터 분석 업무를 
# 쉽게 처리할수 있게 해줌


# import pandas as pd

# #딕셔너리를 시리즈로 묶기
# dict_data = {'a': 1, 'b':2, 'c':3}
# series = pd.Series(dict_data)
# series

# #딕셔너리의 인덱스만 출력
# series.index
# #딕셔너리의 값만 출력
# series.values

# #리스트를 시리즈로 묶기
# list_data = ['a','b','c']
# series_2 = pd.Series(list_data2)
# series_2

# #리스트의 인덱스를 변경해주기
# series_3 = pd.Series(list_data, index = ['에이','비','씨'])
# series_3

# #시리즈도 리스트[]나 튜플, 딕셔너리{}과 같이 인덱싱이나 슬라이싱이 사용가능

# #인덱스가 국가, 밸류가 수도인 시리즈인 딕셔너리만들기
# capital= pd.Series({'Korea':'Seoul',
#                     'Japan':'Tokyo',
#                     'China':'Beijing',
#                     'India':'New Delhi',
#                     'Singapore':'Singapore'})
# capital
# #한국 수도값 출력
# capital['Korea']
# #한번에 여러개 인덱스 출력가능, 리스트 안에 리스트를 넣어야 출력됨.
# capital[['Japan','India']]
# #리스트 순서에 따라 출력 가능
# capital[0]
# capital[0:3] #0이상 3미만 출력
# capital[[0,3]]
# capital[[2,4]]

# #시리즈는 사칙연산이 가능
# series_1 = pd.Series([1,2,3])
# series_2 = pd.Series([4,5,6])

# series_1
# series_2

# #시리즈는 사칙연산이가능 
# series_1 + series_2
# series_1 * series_2
# series_2 * 3
# series_1 / series_2
